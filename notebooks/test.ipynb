# %% [markdown]
# # Test

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_dir = '../data/nychealth-coronavirus-data/'

# %%
df = pd.read_csv(data_dir + 'tests-by-zcta.csv')
df
# Out:
#      MODZCTA  Positive  Total  zcta_cum.perc_pos
# 0        NaN      4530   4534              99.91
# 1    10001.0       146    321              45.48
# 2    10002.0       341    684              49.85
# 3    10003.0       198    464              42.67
# 4    10004.0        20     45              44.44
# ..       ...       ...    ...                ...
# 173  11691.0       660    992              66.53
# 174  11692.0       169    267              63.30
# 175  11693.0       120    198              60.61
# 176  11694.0       201    367              54.77
# 177  11697.0        31     75              41.33
#
# [178 rows x 4 columns]

# %%
df[['Positive', 'Total']].sum()
# Out:
# Positive     60435
# Total       104096
# dtype: int64

# %%
summary_df = pd.read_csv(data_dir + 'summary.csv', header=None)
summary_df
# Out:
#                       0                    1
# 0                Cases:                41771
# 1  Total hospitalized*:                 8549
# 2               Deaths:                 1096
# 3                As of:  March 31, 5:00 p.m.

# %%
boro_df = pd.read_csv(data_dir + 'boro.csv')
boro_df
# Out:
#    BORO      ratewt     boro_label
# 0     5  529.912031          BRONX
# 1    47  411.774636       BROOKLYN
# 2    61  351.295569      MANHATTAN
# 3    81  561.470484         QUEENS
# 4    85  463.424507  STATEN ISLAND

# %%
by_age_df = pd.read_csv(data_dir + 'by-age.csv')
by_age_df
# Out:
#             AGE_GROUP  COVID_CASE_RATE  HOSPITALIZED_CASE_RATE  DEATH_RATE
# 0          0-17 years            43.84                    4.29        0.06
# 1         18-44 years           514.80                   45.46        1.99
# 2         45-64 years           714.43                  155.40       12.60
# 3         65-75 years           717.33                  261.19       36.47
# 4  75 and older years           706.80                  351.39       93.97
# 5      Citywide total           497.35                  101.79       13.05

# %%
by_sex_df = pd.read_csv(data_dir + 'by-sex.csv')
by_sex_df
# Out:
#         SEX_GROUP  COVID_CASE_RATE  HOSPITALIZED_CASE_RATE  DEATH_RATE
# 0          Female           425.18                   78.65        9.13
# 1            Male           575.22                  127.14       17.32
# 2  Citywide total           497.35                  101.79       13.05

# %%
chd_df = pd.read_csv(data_dir + 'case-hosp-death.csv')
chd_df
# Out:
#    DATE_OF_INTEREST  NEW_COVID_CASE_COUNT  HOSPITALIZED_CASE_COUNT  \
# 0            3/2/20                     1                      1.0
# 1            3/3/20                     2                      5.0
# 2            3/4/20                     9                      3.0
# 3            3/5/20                     2                      4.0
# 4            3/6/20                     8                      5.0
# 5            3/7/20                    11                      9.0
# 6            3/8/20                    20                     18.0
# 7            3/9/20                    53                     27.0
# 8           3/10/20                    70                     36.0
# 9           3/11/20                   156                     46.0
# 10          3/12/20                   355                     76.0
# 11          3/13/20                   607                    117.0
# 12          3/14/20                   626                    154.0
# ...

# %%
testing_df = pd.read_csv(data_dir + 'testing.csv')
testing_df
# Out:
#    extract_date specimen_date  Number_tested  Number_confirmed  \
# 0       3/31/20       1/29/20              1                 0
# 1       3/31/20        2/2/20              2                 0
# 2       3/31/20        2/4/20              1                 0
# 3       3/31/20        2/5/20              1                 0
# 4       3/31/20        2/8/20              1                 0
# 5       3/31/20       2/23/20              1                 1
# 6       3/31/20       2/26/20              1                 0
# 7       3/31/20       2/27/20              2                 0
# 8       3/31/20       2/29/20              3                 1
# 9       3/31/20        3/1/20              1                 0
# 10      3/31/20        3/2/20              3                 0
# 11      3/31/20        3/3/20              9                 0
# 12      3/31/20        3/4/20             36                 5
# 13      3/31/20        3/5/20             54                 3
# ...
